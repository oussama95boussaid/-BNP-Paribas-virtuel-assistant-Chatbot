# %% [markdown]
# # BNP Paribas Web Scraper for RAG Pipeline
#
# **This notebook scrapes data from BNP Paribas website and prepares it for RAG (Retrieval-Augmented Generation).**
#
# **Features:**
# - Scrapes content from multiple categories
# - Cleans and structures data
# - Exports in multiple formats (JSON)
# - Ready for vector databases and RAG systems

# %%
import sys
import scipy
import numpy as np
import matplotlib
import pandas as pd
import sklearn
from pandas.plotting import scatter_matrix
from matplotlib import pyplot


bnp_link = pd.read_csv('/content/BNPParibas_Top10_Chatbot_Links.csv')
print(bnp_link.shape)
bnp_link.head(20)
# Out:
# (10, 3)
#                   Catégorie  \
# 0  Accueil / Vue d’ensemble
# 1        Comptes & Formules
# 2         Épargne & Livrets
# 3     Crédits & Financement
# 4          Cartes bancaires
# 5        Bourse & Placement
# 6                Assurances
# 7     FAQ / Aide & Services
# 8       Tarifs & Conditions
# 9      Sécurité / Connexion
#
#                                                  URL  \
# 0                       https://mabanque.bnpparibas/
# 1  https://mabanque.bnpparibas/fr/devenir-client/...
# 2  https://mabanque.bnpparibas/fr/epargner/compte...
# 3  https://mabanque.bnpparibas/fr/vos-besoins/vos...
# 4  https://mabanque.bnpparibas/fr/gerer/services-...
# 5  https://mabanque.bnpparibas/fr/bourse/nos-offr...
# 6             https://mabanque.bnpparibas/fr/assurer
# 7  https://mabanque.bnpparibas/fr/ma-banque-et-mo...
# 8  https://mabanque.bnpparibas/fr/notre-offre/tarifs
# 9            https://mabanque.bnpparibas/fr/securite
#
#                                          Description
# 0  Présentation générale et liens vers toutes les...
# 1  Détails sur les comptes BNP Paribas, formules ...
# 2  Produits d’épargne : Livret A, LDDS, PEL, CEL,...
# 3  Solutions de financement : prêts personnels, a...
# 4  Cartes Visa Classic, Premier, Infinite : avant...
# 5  Informations sur la bourse et les placements f...
# 6    Assurances habitation, auto, santé, prévoyance.
# 7      Page FAQ et services d’accompagnement client.
# 8  Grille tarifaire BNP Paribas et conditions gén...
# 9  Conseils sécurité et prévention des fraudes ba...

# %%
bnp_link_df = bnp_link[bnp_link['Catégorie'] != 'Assurances']
display(bnp_link_df)
# Out:
#                   Catégorie  \
# 0  Accueil / Vue d’ensemble
# 1        Comptes & Formules
# 2         Épargne & Livrets
# 3     Crédits & Financement
# 4          Cartes bancaires
# 5        Bourse & Placement
# 7     FAQ / Aide & Services
# 8       Tarifs & Conditions
# 9      Sécurité / Connexion
#
#                                                  URL  \
# 0                       https://mabanque.bnpparibas/
# 1  https://mabanque.bnpparibas/fr/devenir-client/...
# 2  https://mabanque.bnpparibas/fr/epargner/compte...
# 3  https://mabanque.bnpparibas/fr/vos-besoins/vos...
# 4  https://mabanque.bnpparibas/fr/gerer/services-...
# 5  https://mabanque.bnpparibas/fr/bourse/nos-offr...
# 7  https://mabanque.bnpparibas/fr/ma-banque-et-mo...
# 8  https://mabanque.bnpparibas/fr/notre-offre/tarifs
# 9            https://mabanque.bnpparibas/fr/securite
#
#                                          Description
# 0  Présentation générale et liens vers toutes les...
# 1  Détails sur les comptes BNP Paribas, formules ...
# 2  Produits d’épargne : Livret A, LDDS, PEL, CEL,...
# 3  Solutions de financement : prêts personnels, a...
# 4  Cartes Visa Classic, Premier, Infinite : avant...
# 5  Informations sur la bourse et les placements f...
# 7      Page FAQ et services d’accompagnement client.
# 8  Grille tarifaire BNP Paribas et conditions gén...
# 9  Conseils sécurité et prévention des fraudes ba...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import json
from pathlib import Path
import re
from IPython.display import display


# Configuration
OUTPUT_DIR = "bnp_rag_documents"
DELAY_BETWEEN_REQUESTS = 2.0  # seconds

# Create output directory
Path(OUTPUT_DIR).mkdir(exist_ok=True)

# Headers for requests
HEADERS = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36"
}

# Store all documents
documents = []

# %%
def clean_text(text):
    """Clean extracted text"""
    text = re.sub(r'\s+', ' ', text)
    text = text.strip()
    return text

# %%
def scrape_page(url, category, description, doc_id):
    """Scrape a single page and extract relevant content"""
    try:
        print(f"Scraping: {category}")
        response = requests.get(url, headers=HEADERS, timeout=15)
        response.raise_for_status()

        soup = BeautifulSoup(response.content, 'html.parser')

        # Remove script and style elements
        for element in soup(['script', 'style', 'nav', 'footer', 'header']):
            element.decompose()

        # Extract title
        title = soup.find('h1')
        title_text = title.get_text(strip=True) if title else category

        # Extract main content
        content_selectors = [
            'main',
            'article',
            '[role="main"]',
            '.content',
            '.main-content',
            '#content'
        ]

        content = None
        for selector in content_selectors:
            content = soup.select_one(selector)
            if content:
                break

        if not content:
            content = soup.find('body')

        # Extract paragraphs and headings
        text_elements = []
        if content:
            for elem in content.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'li']):
                text = clean_text(elem.get_text())
                if len(text) > 20:
                    text_elements.append(text)

        full_text = ' '.join(text_elements)

        # Create document structure
        document = {
            'id': f"doc_{doc_id}",
            'category': category,
            'title': title_text,
            'url': url,
            'description': description,
            'content': full_text,
            'word_count': len(full_text.split()),
            'scraped_at': time.strftime('%Y-%m-%d %H:%M:%S')
        }

        print(f"   ✓ Extracted {len(full_text.split())} words\n")
        return document

    except requests.exceptions.RequestException as e:
        print(f"   ✗ Error: {e}\n")
        return {
            'id': f"doc_{doc_id}",
            'category': category,
            'title': category,
            'url': url,
            'description': description,
            'content': f"Error: Could not scrape this page. {str(e)}",
            'word_count': 0,
            'scraped_at': time.strftime('%Y-%m-%d %H:%M:%S'),
            'error': str(e)
        }

print(f"Starting scraping process...\n")
# Out:
# Starting scraping process...

# %%
# Scrape each URL
for idx, row in bnp_link_df.iterrows():
    category = row['Catégorie']
    url = row['URL']
    description = row['Description']

    document = scrape_page(url, category, description, idx)
    documents.append(document)

    # Be polite - add delay between requests
    if idx < len(bnp_link_df) - 1:
        time.sleep(DELAY_BETWEEN_REQUESTS)




print(f"{'='*60}")
print(f"✅ Scraping complete! {len(documents)} documents collected.")
print(f"{'='*60}\n")
# Out:
# Scraping: Accueil / Vue d’ensemble
#    ✓ Extracted 1865 words
#
# Scraping: Comptes & Formules
#    ✗ Error: 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire
#
# Scraping: Épargne & Livrets
#    ✓ Extracted 170 words
#
# Scraping: Crédits & Financement
#    ✓ Extracted 14 words
#
# Scraping: Cartes bancaires
#    ✗ Error: 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/gerer/services-bancaires/cartes
#
# Scraping: Bourse & Placement
#    ✓ Extracted 567 words
#
# Scraping: FAQ / Aide & Services
#    ✓ Extracted 2449 words
#
# Scraping: Tarifs & Conditions
#    ✗ Error: 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/notre-offre/tarifs
#
# Scraping: Sécurité / Connexion
#    ✗ Error: 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/securite
#
# ============================================================
# ✅ Scraping complete! 9 documents collected.
# ============================================================

# %%
documents
# Out:
# [{'id': 'doc_0',
#   'category': 'Accueil / Vue d’ensemble',
#   'title': 'BNP PARIBAS BANQUE ET ASSURANCES',
#   'url': 'https://mabanque.bnpparibas/',
#   'description': 'Présentation générale et liens vers toutes les offres.',
#   'content': 'BNP PARIBAS BANQUE ET ASSURANCES Jusqu’à 270 € d’avantages offerts (1) Pour toute première ouverture d\'un compte BNP Paribas et d\'une carte Visa Premier avec l\'offre Esprit Libre Référence Soit 80 € offerts + 1 an de gratuité aux services essentiels Esprit Libre. Leader européen des services bancaires (2) Leader européen des services bancaires (2) Prix du meilleur conseil épargne 2024 (3) Prix du meilleur conseil épargne 2024 (3) Des conseillers experts en ligne et en agence Des conseillers experts en ligne et en agence Choisissez la carte qui vous convient Activation de la carte dès le premier paiement sans contact Vos plafonds de retrait et de paiement personnalisables Activation de la carte dès le premier paiement sans contact Activation de la carte dès le premier paiement sans contact Vos plafonds de retrait et de paiement personnalisables Vos plafonds de retrait et de paiement personnalisables Carte à débit immédiat ou différé Assistance médicale et remboursement des frais médicaux Assistance aux voyageurs et animaux domestiques, rapatriement Assistance juridique à l\'étranger Carte à débit immédiat ou différé Carte à débit immédiat ou différé Assistance médicale et remboursement des frais médicaux Assistance médicale et remboursement des frais médicaux Assistance aux voyageurs et animaux domestiques, rapatriement Assistance aux voyageurs et animaux domestiques, rapatriement Assistance juridique à l\'étranger Assistance juridique à l\'étranger Le plus d\'avantages Inclus les services de la carte VIsa Classic Avantages et réductions auprès de nos partenaires dans des domaines variés Assurance voyage (annulation de vol, perte/vol de bagages, etc.) Garantie de véhicule location Garantie neige et montagne Inclus les services de la carte VIsa Classic Inclus les services de la carte VIsa Classic Avantages et réductions auprès de nos partenaires dans des domaines variés Avantages et réductions auprès de nos partenaires dans des domaines variés Assurance voyage (annulation de vol, perte/vol de bagages, etc.) Assurance voyage (annulation de vol, perte/vol de bagages, etc.) Garantie de véhicule location Garantie de véhicule location Garantie neige et montagne Garantie neige et montagne (4) Chacun des produits et services inclus dans l\'offre groupée de services Esprit Libre peut être souscrit séparément. Avec la carte Visa Infinite, vous bénéficiez d’une carte haut de gamme, d’une capacité de dépense à votre mesure en France comme à l’étranger, d’une conciergerie 24h/24 et 7j/7. Disponible uniquement en agence afin de vous garantir un service sur mesure. Près de chez vous ou en ligne, nos experts vous accompagnent Nos conseillers vous font bénéficier de leur expertise pour vous offrir des solutions à la hauteur de vos ambitions. Nos conseillers vous font bénéficier de leur expertise pour vous offrir des solutions à la hauteur de vos ambitions. À chaque étape de votre vie, nous sommes à vos côtés pour concrétiser vos projets et anticiper vos besoins.\u200b À chaque étape de votre vie, nous sommes à vos côtés pour concrétiser vos projets et anticiper vos besoins.\u200b Explorez notre réseau national d’agences Trouvez l’agence la plus proche de chez vous et consultez les horaires de prises de rendez-vous avec nos conseillers experts. Le meilleur de votre banque dans une application mobile Des alertes personnalisables en temps réel Des alertes personnalisables en temps réel Enrichissez vos connaissances avec les Avis d\'experts Enrichissez vos connaissances avec les Avis d\'experts Une vue d\'ensemble de votre épargne Une vue d\'ensemble de votre épargne Évaluation des clients Découvrir l’application Une offre de produits adaptée à tous vos besoins Préparer l\'avenir de vos enfants Anticipez leurs besoins et développez leur patrimoine financier. Préparer l\'avenir de vos enfants Anticipez leurs besoins et développez leur patrimoine financier. Concrétisez vos projets immobiliers Soyez accompagné dans le financement ou l ...
#   'word_count': 1865,
#   'scraped_at': '2025-10-19 22:47:48'},
#  {'id': 'doc_1',
#   'category': 'Comptes & Formules',
#   'title': 'Comptes & Formules',
#   'url': 'https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire',
#   'description': 'Détails sur les comptes BNP Paribas, formules et conditions.',
#   'content': 'Error: Could not scrape this page. 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire',
#   'word_count': 0,
#   'scraped_at': '2025-10-19 22:47:51',
#   'error': '404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire'},
#  {'id': 'doc_2',
#   'category': 'Épargne & Livrets',
#   'title': 'Épargne & Livrets',
#   'url': 'https://mabanque.bnpparibas/fr/epargner/comptes-livrets-epargne',
#   'description': 'Produits d’épargne : Livret A, LDDS, PEL, CEL, etc.',
#   'content': "DÉCOUVREZ NOS COMPTES ÉPARGNE & LIVRETS Un livret d'épargne disponible à tout moment et défiscalisé. Livret Développement Durable et Solidaire Une épargne sécurisée et disponible à tout moment. Un contrat d’épargne disponible, rémunéré et sans plafond. Un contrat d'épargne disponible à versements libres réservé aux jeunes entre 12 et 25 ans. Livret d'épargne populaire Une épargne performante réservée à ceux qui paient peu d'impôts. Le dépôt à terme ou compte à terme est un contrat d'épargne avec un taux fixe garanti et une durée de placement connus à l'avance. OFFRE DONT LA COMMERCIALISATION EST CLOSE Compte Weezbee (commercialisation close) Le Compte Weezbee est un contrat d’épargne disponible, à versements libres et sans plafond, réservé aux mineurs. NOS OUTILS ET CONSEILS Simulez votre épargne sur nos produits BNP Paribas ! Comparez facilement les produits d'épargne BNP Paribas ! Envie de connaître votre personnalité financière ? Faites le test, découvrez-la et inspirez-vous d’un épargnant comme vous !\u200b Découvrez notre fiche info Fiscalité de l'Épargne Emploi des ressources Livrets A et LDDS collectées",
#   'word_count': 170,
#   'scraped_at': '2025-10-19 22:47:54'},
#  {'id': 'doc_3',
#   'category': 'Crédits & Financement',
#   'title': 'Crédits & Financement',
#   'url': 'https://mabanque.bnpparibas/fr/vos-besoins/vos-projets',
#   'description': 'Solutions de financement : prêts personnels, auto, immobilier, études.',
#   'content': "CRÉATION D'ENTREPRISE COMMENT PRÉPARER SA SUCCESSION ? RECEVOIR UNE SUCCESSION Réduire son empreinte écologique",
#   'word_count': 14,
#   'scraped_at': '2025-10-19 22:47:56'},
#  {'id': 'doc_4',
#   'category': 'Cartes bancaires',
#   'title': 'Cartes bancaires',
#   'url': 'https://mabanque.bnpparibas/fr/gerer/services-bancaires/cartes',
#   'description': 'Cartes Visa Classic, Premier, Infinite : avantages, assurances, tarifs.',
#   'content': 'Error: Could not scrape this page. 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/gerer/services-bancaires/cartes',
#   'word_count': 0,
#   'scraped_at': '2025-10-19 22:47:59',
#   'error': '404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/gerer/services-bancaires/cartes'},
#  {'id': 'doc_5',
#   'category': 'Bourse & Placement',
#   'title': 'Nos offres et Services d’investissement en Bourse',
#   'url': 'https://mabanque.bnpparibas/fr/bourse/nos-offres-et-services-bourse',
#   'description': 'Informations sur la bourse et les placements financiers.',
#   'content': "Nos offres et Services d’investissement en Bourse Découvrez l’ensemble des offres, des services et des comptes dédiés proposés par BNP Paribas pour vous guider dans vos investissements en Bourse. Développez votre connaissance de la Bourse et des Marchés financiers Trouvez l’offre la plus adaptée à votre profil d’investisseur grâce aux outils et services performants de BNP Paribas. Comment investir en Bourse avec BNP Paribas ? 1. Créez votre Profil financier 2. Ouvrez un compte dédié 3. Sélectionnez une offre tarifaire adaptée à vos besoins 4. Investissez en Bourse Commencez les investissements en Bourse Qu’est-ce que la Bourse ? Pourquoi et comment investir ? Découvrez toutes les réponses à ces questions. Créez votre Profil financier Le Profil financier est réalisé dans votre intérêt. Il nous permet de vous accompagner dans vos décisions d'investissement. Ouvrez un compte dédié pour l’investissement en bourse Ouvrez en ligne facilement et rapidement un compte dédié à la Bourse Vous pouvez dorénavant ouvrir un compte Titres, PEA, PEA-PME grâce à la souscription 100 % en ligne. Comparez nos différents produits, afin de déterminer celui qui vous convient le mieux et de découvrir leurs différences. Nous vous remboursons les frais de transfert de votre compte PEA ou PEA-PME dans la limite d'un forfait de 150 € (si le montant minimum de votre compte Bourse est de 5 000 €). Compte d’Instruments Financiers Investissez sur une gamme étendue de valeurs mobilières, sans limitation de plafond, ni durée de détention imposée. Plan d’Épargne en Actions Dynamisez votre portefeuille en investissant dans des valeurs mobilières françaises et européennes tout en bénéficiant d'un cadre fiscal avantageux. Plan d’Épargne en Actions PME-ETI Diversifiez votre épargne en investissant dans les petites et moyennes entreprises - entreprises tailles intermédiaires en bénéficiant d'un cadre fiscal avantageux. Choisissez une offre Bourse adaptée Une offre pour les investisseurs exécutant plus de 4 ordres de Bourse par an, d'un montant moyen inférieur ou égal à 3 000 €. Une offre pour les profils actifs exécutant plus de 8 ordres de Bourse par an, d'un montant moyen inférieur ou égal à 8 000 €. Gratuité des droits de garde (sous conditions). Explorez les outils de prise de décision et d’analyse du Marché pour développer votre connaissance de la Bourse et des Marchés financiers à l’aide de BNP Paribas. Nos outils d'aide à la décision Investissez dans ce qui vous inspire, des thèmes populaires aux stratégies d'experts. Identifiez les figures graphiques et les évènements techniques pour guider vos stratégies d'investissement. Retrouvez les Marchés en direct et le passage d’ordre Les Marchés en direct Découvrez notre espace dédié pour gérer et suivre les analyses, les actualités et toutes les cotations en Bourse en direct, sur le site mabanque.bnpparibas. Recevez par email l'essentiel de l'actualité des Marchés Besoin d’aide sur nos produits et services ? Faites vous accompagner par un conseiller de notre équipe Net Epargne et Prévoyance pour passer vos ordres En savoir plus sur la Bourse Fiscalité, Bourse et Titres Découvrez tout ce qu'il faut savoir sur la fiscalité, la Bourse et les Titres. Opérations sur titres (OST) Répondez aux opérations sur titres depuis votre espace bourse. Assemblée Générale et vote en ligne Votez en ligne en toute sécurité les résolutions lors d’une assemblée générale. Tout ce que vous devez savoir sur les droits de garde. Consulter son épargne n’a jamais été aussi simple. Facile d’accès, complet et personnalisable, le widget Epargne est disponible depuis l’application Mes Comptes.",
#   'word_count': 567,
#   'scraped_at': '2025-10-19 22:48:02'},
#  {'id': 'doc_7',
#   'category': 'FAQ / Aide & Services',
#   'title': 'FAQ / Aide & Services',
#   'url': 'https://mabanque.bnpparibas/fr/ma-banque-et-moi/nos-services-accompagnement/tous-nos-services-d-accompagnement',
#   'description': 'Page FAQ et services d’accompagnement client.',
#   'content': "Un accompagnement bancaire au plus proche de vos attentes Une relation en agence et à distance selon vos préférences. Des conseillers formés et à votre écoute pour apporter une réponse sur mesure à vos besoins. Une offre de produits et services adaptés à votre patrimoine, vos valeurs et vos convictions. nos services d'accompagnement Votre équipe Proximité vous accompagne. Un suivi personnalisé pour la gestion de votre patrimoine. Principales caractéristiques des services d'accompagnement Service Proximité Découvrir Service Affinité Découvrir Abonnement mensuel au service 0€ 12 € / mois(1) Accompagnement personnalisé Une équipe de conseillers Un conseiller dédié Services exclusifs - · Rendez-vous Bilan Annuel & Perspectives(2) · Conseil et suivi patrimonial personnalisé Service Client (service d'accueil téléphonique) Service Client BNP Paribas Affinité Connect Offres groupées Esprit Libre Référence (avec 1 carte Premier) 15,99 € / mois 9,83 € / mois Carte Premier hors Esprit Libre 144 € / an 72 € / an Frais sur versements contrat d'Assurance vie ou de capitalisation 2,75 % maximum du montant versé (hors offre promotionnelle) 0,50 % Frais sur versements Plan d'Epargne retraite individuel En cours de vie des contrats, des frais sont prélevés (notamment des frais sur versements, d’arbitrage, de gestion …) selon les conditions définies dans les dispositions contractuelles. Les montants investis sur les supports en unités de compte ne sont pas garantis mais sont sujets à des fluctuations à la hausse comme à la baisse dépendant en particulier de l’évolution des marchés financiers et/ou immobiliers. Les supports en unités de compte présentent donc un risque de perte en capital pouvant être partielle ou totale. L’Assureur ne s'engage par ailleurs, que sur le nombre d'unités de compte, mais pas sur leur valeur. 2,50 % maximum du montant versé (hors offre promotionnelle) Des offres commerciales peuvent être proposées sur les frais sur versements réalisés à partir de votre espace personnel sur le site mabanque.bnpparibas.com 0,50 % Des offres commerciales peuvent être proposées sur les frais sur versements réalisés à partir de votre espace personnel sur le site mabanque.bnpparibas.com Frais de tenue de compte 2,60 € / mois(3) Gratuit Newsletters Actualités financières et sujets patrimoniaux (Épargne financière, Prévoyance, Assurance, Immobilier etc...) En savoir plus sur le Service Proximité En savoir plus sur le Service Affinité Abonnement mensuel au service 0€ 12 € / mois(1) Accompagnement personnalisé Une équipe de conseillers Un conseiller dédié Services exclusifs - · Rendez-vous Bilan Annuel & Perspectives(2) · Conseil et suivi patrimonial personnalisé Service Client (service d'accueil téléphonique) Service Client BNP Paribas Affinité Connect Offres groupées Esprit Libre Référence (avec 1 carte Premier) 15,99 € / mois 9,83 € / mois Carte Premier hors Esprit Libre 144 € / an 72 € / an Frais sur versements contrat d'Assurance vie ou de capitalisation 2,75 % maximum du montant versé (hors offre promotionnelle) 0,50 % Frais sur versements Plan d'Epargne retraite individuel En cours de vie des contrats, des frais sont prélevés (notamment des frais sur versements, d’arbitrage, de gestion …) selon les conditions définies dans les dispositions contractuelles. Les montants investis sur les supports en unités de compte ne sont pas garantis mais sont sujets à des fluctuations à la hausse comme à la baisse dépendant en particulier de l’évolution des marchés financiers et/ou immobiliers. Les supports en unités de compte présentent donc un risque de perte en capital pouvant être partielle ou totale. L’Assureur ne s'engage par ailleurs, que sur le nombre d'unités de compte, mais pas sur leur valeur. 2,50 % maximum du montant versé (hors offre promotionnelle) Des offres commerciales peuvent être proposées sur les frais sur versements réalisés à partir de votre espace personnel sur le site mabanque.bnpparibas.com 0,50 % Des offres comme ...
#   'word_count': 2449,
#   'scraped_at': '2025-10-19 22:48:04'},
#  {'id': 'doc_8',
#   'category': 'Tarifs & Conditions',
#   'title': 'Tarifs & Conditions',
#   'url': 'https://mabanque.bnpparibas/fr/notre-offre/tarifs',
#   'description': 'Grille tarifaire BNP Paribas et conditions générales.',
#   'content': 'Error: Could not scrape this page. 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/notre-offre/tarifs',
#   'word_count': 0,
#   'scraped_at': '2025-10-19 22:48:07',
#   'error': '404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/notre-offre/tarifs'},
#  {'id': 'doc_9',
#   'category': 'Sécurité / Connexion',
#   'title': 'Sécurité / Connexion',
#   'url': 'https://mabanque.bnpparibas/fr/securite',
#   'description': 'Conseils sécurité et prévention des fraudes bancaires.',
#   'content': 'Error: Could not scrape this page. 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/securite',
#   'word_count': 0,
#   'scraped_at': '2025-10-19 22:48:09',
#   'error': '404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/securite'}]

# %%
# Save as JSON (good for vector databases)
json_path = Path(OUTPUT_DIR) / "rag_documents.json"
with open(json_path, 'w', encoding='utf-8') as f:
    json.dump(documents, f, ensure_ascii=False, indent=2)
print(f"✓ Saved JSON: {json_path}")
# Out:
# ✓ Saved JSON: bnp_rag_documents/rag_documents.json

# %%
# Save as JSONL (one document per line - common RAG format)
jsonl_path = Path(OUTPUT_DIR) / "rag_documents.jsonl"
with open(jsonl_path, 'w', encoding='utf-8') as f:
    for doc in documents:
        f.write(json.dumps(doc, ensure_ascii=False) + '\n')
print(f"✓ Saved JSONL: {jsonl_path}")
# Out:
# ✓ Saved JSONL: bnp_rag_documents/rag_documents.jsonl

# %%
# Create summary DataFrame
summary_df = pd.DataFrame([{
    'id': doc['id'],
    'category': doc['category'],
    'title': doc['title'],
    'url': doc['url'],
    'word_count': doc['word_count'],
    'has_error': 'error' in doc
} for doc in documents])

# Save summary as CSV
csv_path = Path(OUTPUT_DIR) / "scraping_summary.csv"
summary_df.to_csv(csv_path, index=False, encoding='utf-8')
print(f"✓ Saved summary: {csv_path}\n")

print("📄 Scraping Summary:")
display(summary_df)
# Out:
# ✓ Saved summary: bnp_rag_documents/scraping_summary.csv
#
# 📄 Scraping Summary:
#       id                  category  \
# 0  doc_0  Accueil / Vue d’ensemble
# 1  doc_1        Comptes & Formules
# 2  doc_2         Épargne & Livrets
# 3  doc_3     Crédits & Financement
# 4  doc_4          Cartes bancaires
# 5  doc_5        Bourse & Placement
# 6  doc_7     FAQ / Aide & Services
# 7  doc_8       Tarifs & Conditions
# 8  doc_9      Sécurité / Connexion
#
#                                                title  \
# 0                   BNP PARIBAS BANQUE ET ASSURANCES
# 1                                 Comptes & Formules
# 2                                  Épargne & Livrets
# 3                              Crédits & Financement
# 4                                   Cartes bancaires
# 5  Nos offres et Services d’investissement en Bourse
# 6                              FAQ / Aide & Services
# 7                                Tarifs & Conditions
# 8                               Sécurité / Connexion
#
#                                                  url  word_count  has_error
# 0                       https://mabanque.bnpparibas/        1865      False
# 1  https://mabanque.bnpparibas/fr/devenir-client/...           0       True
# 2  https://mabanque.bnpparibas/fr/epargner/compte...         170      False
# 3  https://mabanque.bnpparibas/fr/vos-besoins/vos...          14      False
# 4  https://mabanque.bnpparibas/fr/gerer/services-...           0       True
# 5  https://mabanque.bnpparibas/fr/bourse/nos-offr...         567      False
# 6  https://mabanque.bnpparibas/fr/ma-banque-et-mo...        2449      False
# 7  https://mabanque.bnpparibas/fr/notre-offre/tarifs           0       True
# 8            https://mabanque.bnpparibas/fr/securite           0       True

# %%
# Calculate statistics
total_words = sum(doc['word_count'] for doc in documents)
errors = sum(1 for doc in documents if 'error' in doc)
success_rate = ((len(documents)-errors)/len(documents)*100)

print(f"\n{'='*60}")
print("📊 STATISTICS")
print(f"{'='*60}")
print(f"  Total documents: {len(documents)}")
print(f"  Total words: {total_words:,}")
print(f"  Errors: {errors}")
print(f"  Success rate: {success_rate:.1f}%")
print(f"{'='*60}\n")

# Create stats DataFrame
stats_df = pd.DataFrame([{
    'Total documents': len(documents),
    'Total words': f"{total_words:,}",
    'Errors': errors,
    'Success rate': f"{success_rate:.1f}%"
}])
display(stats_df)
# Out:
# ============================================================
# 📊 STATISTICS
# ============================================================
#   Total documents: 9
#   Total words: 5,065
#   Errors: 4
#   Success rate: 55.6%
# ============================================================
#    Total documents Total words  Errors Success rate
# 0                9       5,065       4        55.6%

# %%
# Preview first 3 documents
print("📖 Preview of scraped documents:\n")
for i, doc in enumerate(documents[:3]):
    print(f"{'='*60}")
    print(f"Document {i+1}: {doc['category']}")
    print(f"{'='*60}")
    print(f"Title: {doc['title']}")
    print(f"URL: {doc['url']}")
    print(f"Word Count: {doc['word_count']}")
    print(f"\nContent Preview (first 500 chars):")
    print(doc['content'][:500] + "...")
    print(f"\n")
# Out:
# 📖 Preview of scraped documents:
#
# ============================================================
# Document 1: Accueil / Vue d’ensemble
# ============================================================
# Title: BNP PARIBAS BANQUE ET ASSURANCES
# URL: https://mabanque.bnpparibas/
# Word Count: 1865
#
# Content Preview (first 500 chars):
# BNP PARIBAS BANQUE ET ASSURANCES Jusqu’à 270 € d’avantages offerts (1) Pour toute première ouverture d'un compte BNP Paribas et d'une carte Visa Premier avec l'offre Esprit Libre Référence Soit 80 € offerts + 1 an de gratuité aux services essentiels Esprit Libre. Leader européen des services bancaires (2) Leader européen des services bancaires (2) Prix du meilleur conseil épargne 2024 (3) Prix du meilleur conseil épargne 2024 (3) Des conseillers experts en ligne et en agence Des conseillers expe...
#
#
# ============================================================
# Document 2: Comptes & Formules
# ============================================================
# Title: Comptes & Formules
# URL: https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire
# Word Count: 0
#
# Content Preview (first 500 chars):
# Error: Could not scrape this page. 404 Client Error: Not Found for url: https://mabanque.bnpparibas/fr/devenir-client/compte-bancaire...
#
#
# ============================================================
# Document 3: Épargne & Livrets
# ============================================================
# Title: Épargne & Livrets
# URL: https://mabanque.bnpparibas/fr/epargner/comptes-livrets-epargne
# Word Count: 170
#
# Content Preview (first 500 chars):
# DÉCOUVREZ NOS COMPTES ÉPARGNE & LIVRETS Un livret d'épargne disponible à tout moment et défiscalisé. Livret Développement Durable et Solidaire Une épargne sécurisée et disponible à tout moment. Un contrat d’épargne disponible, rémunéré et sans plafond. Un contrat d'épargne disponible à versements libres réservé aux jeunes entre 12 et 25 ans. Livret d'épargne populaire Une épargne performante réservée à ceux qui paient peu d'impôts. Le dépôt à terme ou compte à terme est un contrat d'épargne avec...

# %%
# Create detailed summary DataFrame
summary_detailed = pd.DataFrame([{
    'ID': doc['id'],
    'Category': doc['category'],
    'Title': doc['title'],
    'Word Count': doc['word_count'],
    'Has Error': 'error' in doc,
    'Scraped At': doc['scraped_at']
} for doc in documents])

print("📊 Detailed Summary:")
display(summary_detailed)
# Out:
# 📊 Detailed Summary:
#       ID                  Category  \
# 0  doc_0  Accueil / Vue d’ensemble
# 1  doc_1        Comptes & Formules
# 2  doc_2         Épargne & Livrets
# 3  doc_3     Crédits & Financement
# 4  doc_4          Cartes bancaires
# 5  doc_5        Bourse & Placement
# 6  doc_7     FAQ / Aide & Services
# 7  doc_8       Tarifs & Conditions
# 8  doc_9      Sécurité / Connexion
#
#                                                Title  Word Count  Has Error  \
# 0                   BNP PARIBAS BANQUE ET ASSURANCES        1865      False
# 1                                 Comptes & Formules           0       True
# 2                                  Épargne & Livrets         170      False
# 3                              Crédits & Financement          14      False
# 4                                   Cartes bancaires           0       True
# 5  Nos offres et Services d’investissement en Bourse         567      False
# 6                              FAQ / Aide & Services        2449      False
# 7                                Tarifs & Conditions           0       True
# 8                               Sécurité / Connexion           0       True
#
#             Scraped At
# 0  2025-10-19 22:47:48
# 1  2025-10-19 22:47:51
# 2  2025-10-19 22:47:54
# 3  2025-10-19 22:47:56
# 4  2025-10-19 22:47:59
# 5  2025-10-19 22:48:02
# 6  2025-10-19 22:48:04
# 7  2025-10-19 22:48:07
# 8  2025-10-19 22:48:09
